# %%
# This is an example snippet!
# To create your own, add a new snippet block to the
# nippets.json file in your jupyter nbextensions directory:
# /nbextensions/snippets/snippets.json
import this

# %% [markdown]
# # IMPORTING PACKAGES

# %% [markdown]
# ## IMPORTANT PACKAGES

# %%
import pandas as pd
import matplotlib.pyplot as mt
import numpy as np

# %% [raw]
# col_names = ['name', 'tamil_marks', 'eng_marks', 'sci_marks', 'soc_marks','class_Name']
# col_names.sort()
# print(col_names.index('name'))
# a

# %%
ds_salaries = pd.read_csv('C:/pyprojects/pyprojects/ds_salaries.csv')

# %%
ds_salaries.shape
# Out:
# (607, 12)

# %%
ds_salaries.aggregate
# Out:
# <bound method DataFrame.aggregate of       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
ds_salaries.boxplot()
# Out:
# <AxesSubplot:>

# %%
ds_salaries.all
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
ds_salaries.head(4)
# Out:
#    SL  work_year          experience_level employment_type  \
# 0   0       2020  Mid Level / Intermediate       FULL TIME
# 1   1       2020              SENIOR LEVEL       FULL TIME
# 2   2       2020              SENIOR LEVEL       FULL TIME
# 3   3       2020  Mid Level / Intermediate       FULL TIME
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3  ProduCONTRACT Data Analyst   20000             USD          20000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE        LARGE
# 1                 JP             0               JP        SMALL
# 2                 GB            50               GB       MEDIUM
# ...

# %%
ds_salaries.tail()
# Out:
#       SL  work_year          experience_level employment_type      job_title  \
# 602  602       2022              SENIOR LEVEL       FULL TIME  Data Engineer
# 603  603       2022              SENIOR LEVEL       FULL TIME  Data Engineer
# 604  604       2022              SENIOR LEVEL       FULL TIME   Data Analyst
# 605  605       2022              SENIOR LEVEL       FULL TIME   Data Analyst
# 606  606       2022  Mid Level / Intermediate       FULL TIME   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
ds_salaries.all
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
ds_salaries.columns
# Out:
# Index(['SL', 'work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
ds_salaries.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13248\2562691135.py in <module>
# ----> 1 ds_salaries.columns()
#
# TypeError: 'Index' object is not callable

# %%
ds_salaries.describe
# Out:
# <bound method NDFrame.describe of       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
ds_salaries.corr
# Out:
# <bound method DataFrame.corr of       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
ds_salaries.corr()
# Out:
#                      SL  work_year    salary  salary_in_usd  remote_ratio
# SL             1.000000   0.886550 -0.096250       0.167025      0.095000
# work_year      0.886550   1.000000 -0.087577       0.170493      0.076314
# salary        -0.096250  -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd  0.167025   0.170493 -0.083906       1.000000      0.132122
# remote_ratio   0.095000   0.076314 -0.014608       0.132122      1.000000

# %%
ds_salaries.plot(x='work_year', y='salary')
# Out:
# <AxesSubplot:xlabel='work_year'>

# %%
ds_salaries.count()
# Out:
# SL                    607
# work_year             607
# experience_level      607
# employment_type       607
# job_title             607
# salary                607
# salary_currency       607
# salary_in_usd         607
# employee_residence    607
# remote_ratio          607
# company_location      607
# company_size          607
# dtype: int64

# %%
ds_salaries.hist()
# Out:
# array([[<AxesSubplot:title={'center':'SL'}>,
#         <AxesSubplot:title={'center':'work_year'}>],
#        [<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'salary_in_usd'}>],
#        [<AxesSubplot:title={'center':'remote_ratio'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
ds_salaries.hist
# Out:
# <bound method hist_frame of       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
ds_salaries.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13248\3729279603.py in <module>
# ----> 1 ds_salaries.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
ds_salaries.cov()
# Out:
#                          SL     work_year        salary  salary_in_usd  \
# SL             3.075467e+04    107.608911 -2.606767e+07   2.078418e+06
# work_year      1.076089e+02      0.479048 -9.361153e+04   8.373244e+03
# salary        -2.606767e+07 -93611.532014  2.385040e+12  -9.194669e+09
# salary_in_usd  2.078418e+06   8373.244252 -9.194669e+09   5.034933e+09
# remote_ratio   6.782178e+02      2.150244 -9.184265e+05   3.816497e+05
#
#                 remote_ratio
# SL                678.217822
# work_year           2.150244
# salary        -918426.476993
# salary_in_usd  381649.674724
# remote_ratio     1657.233269

# %%
ds_salaries
# Out:
#       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
ds_salaries
# Out:
#       SL  work_year          experience_level employment_type  \
# 0      0       2020  Mid Level / Intermediate       FULL TIME
# 1      1       2020              SENIOR LEVEL       FULL TIME
# 2      2       2020              SENIOR LEVEL       FULL TIME
# 3      3       2020  Mid Level / Intermediate       FULL TIME
# 4      4       2020              SENIOR LEVEL       FULL TIME
# ..   ...        ...                       ...             ...
# 602  602       2022              SENIOR LEVEL       FULL TIME
# 603  603       2022              SENIOR LEVEL       FULL TIME
# 604  604       2022              SENIOR LEVEL       FULL TIME
# 605  605       2022              SENIOR LEVEL       FULL TIME
# 606  606       2022  Mid Level / Intermediate       FULL TIME
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...
